# %% [markdown]
# Question 1: Compare NLTK and spaCy
#
# NLTK (Natural Language Toolkit) and spaCy are popular Python libraries used for Natural Language Processing (NLP). However, they differ in purpose, design, and performance.

# %% [markdown]
# | Feature          | NLTK                                          | spaCy                                              |
# | ---------------- | --------------------------------------------- | -------------------------------------------------- |
# | Purpose          | Educational and research-oriented NLP toolkit | Industrial-strength NLP library                    |
# | Ease of Use      | Requires more manual coding                   | Easier pipeline-based usage                        |
# | Performance      | Slower for large datasets                     | Highly optimized and faster                        |
# | Features         | Tokenization, stemming, tagging, parsing      | Tokenization, POS tagging, NER, dependency parsing |
# | Machine Learning | Limited built-in ML support                   | Supports deep learning frameworks                  |
# | Use Case         | Teaching and prototyping                      | Production NLP systems                             |

# %% [markdown]
# Question 2: What is TextBlob?
#
# TextBlob is a simple Python library built on top of NLTK and Pattern that simplifies common NLP tasks.
#
# Key Features
#
# Sentiment analysis
#
# Translation
#
# Part-of-speech tagging
#
# Tokenization
#
# Noun phrase extraction
#
# Text classification

# %%
from textblob import TextBlob

text = TextBlob("I love learning Natural Language Processing")

print(text.sentiment)
# Out:
# Sentiment(polarity=0.3, subjectivity=0.5)

# %% [markdown]
# Question 3: Role of Stanford NLP
#
# Stanford NLP (now called Stanford CoreNLP) is a powerful NLP toolkit developed by Stanford University.
#
# Role in Academic Research
#
# Linguistic analysis
#
# Dependency parsing
#
# Named Entity Recognition
#
# Sentiment analysis
#
# Used in computational linguistics research
#
# Role in Industry
#
# Chatbots
#
# Machine translation
#
# Information extraction
#
# Search engines
#
# Question answering systems
#
# Key Components
#
# POS Tagger
#
# Parser
#
# Named Entity Recognizer
#
# Sentiment Analyzer
#
# Coreference Resolution
#
# Conclusion
#
# Stanford NLP is widely used in both research and industry because of its highly accurate linguistic models.

# %% [markdown]
# Question 4: Architecture and Working of RNN
#
# A Recurrent Neural Network (RNN) is a neural network designed for sequential data like text, speech, or time series.
#
# Architecture
#
# Components:
#
# Input Layer
#
# Hidden Layer with recurrence
#
# Output Layer
#
# Unlike traditional neural networks, RNNs reuse the hidden state from the previous step.

# %% [markdown]
# Question 5: Difference Between LSTM and GRU
#
# Both LSTM (Long Short-Term Memory) and GRU (Gated Recurrent Unit) are advanced RNN architectures

# %% [markdown]
# | Feature        | LSTM                        | GRU                            |
# | -------------- | --------------------------- | ------------------------------ |
# | Gates          | Input, Forget, Output gates | Update and Reset gates         |
# | Complexity     | More complex                | Simpler                        |
# | Parameters     | More parameters             | Fewer parameters               |
# | Training Speed | Slower                      | Faster                         |
# | Performance    | Better for long sequences   | Efficient for smaller datasets |

# %%
# Question 6: TextBlob Sentiment Analysis Program
# Python Code
from textblob import TextBlob

text = """I had a great experience using the new mobile banking app.
The interface is intuitive, and customer support was quick to resolve my issue.
However, the app did crash once during a transaction, which was frustrating."""

blob = TextBlob(text)

print("Polarity:", blob.sentiment.polarity)
print("Subjectivity:", blob.sentiment.subjectivity)
# Out:
# Polarity: 0.21742424242424244
# Subjectivity: 0.6511363636363636

# %%
# Question 7: Tokenization and Frequency Distribution using NLTK
# Python Code
import nltk
nltk.download('punkt_tab') # Downloading 'punkt_tab' as suggested by the error
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

text = """Natural Language Processing (NLP) is a fascinating field that combines linguistics,
computer science, and artificial intelligence. It enables machines to understand,
interpret, and generate human language."""

tokens = word_tokenize(text)

print("Tokens:")
print(tokens)

fdist = FreqDist(tokens)

print("\nWord Frequency:")
print(fdist.most_common(10))
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# Tokens:
# ['Natural', 'Language', 'Processing', '(', 'NLP', ')', 'is', 'a', 'fascinating', 'field', 'that', 'combines', 'linguistics', ',', 'computer', 'science', ',', 'and', 'artificial', 'intelligence', '.', 'It', 'enables', 'machines', 'to', 'understand', ',', 'interpret', ',', 'and', 'generate', 'human', 'language', '.']
#
# Word Frequency:
# [(',', 4), ('and', 2), ('.', 2), ('Natural', 1), ('Language', 1), ('Processing', 1), ('(', 1), ('NLP', 1), (')', 1), ('is', 1)]

# %%
# Question 8: LSTM Model in Keras
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
import numpy as np # Import numpy

texts = [
"I love this project",
"This is an amazing experience",
"I hate waiting in line",
"This is the worst service",
"Absolutely fantastic!"
]

labels = [1,1,0,0,1]
labels = np.array(labels, dtype=np.float32) # Convert labels to a numpy array of float32

tokenizer = Tokenizer()
tokenizer.fit_on_texts(texts)

sequences = tokenizer.texts_to_sequences(texts)

padded = pad_sequences(sequences)

model = Sequential()
model.add(Embedding(input_dim=50, output_dim=8))
model.add(LSTM(16))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit(padded, labels, epochs=10)

print("Model trained successfully")
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.0000e+00 - loss: 0.6959
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.6000 - loss: 0.6947
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.6000 - loss: 0.6936
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.6000 - loss: 0.6924
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6000 - loss: 0.6912
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.6000 - loss: 0.6901
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6000 - loss: 0.6890
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.6000 - loss: 0.6878
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.6000 - loss: 0.6866
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.6000 - loss: 0.6855
# Model trained successfully

# %%
# Question 9: spaCy NLP Pipeline
import spacy

nlp = spacy.load("en_core_web_sm")

text = """Homi Jehangir Bhabha was an Indian nuclear physicist who played a key role
in the development of India’s atomic energy program."""

doc = nlp(text)

print("Tokens and Lemmas:")
for token in doc:
    print(token.text, "->", token.lemma_)

print("\nNamed Entities:")
for ent in doc.ents:
    print(ent.text, "-", ent.label_)
# Out:
# Tokens and Lemmas:
# Homi -> Homi
# Jehangir -> Jehangir
# Bhabha -> Bhabha
# was -> be
# an -> an
# Indian -> indian
# nuclear -> nuclear
# physicist -> physicist
# who -> who
# played -> play
# a -> a
# key -> key
# role -> role
#
#  ->
#
# in -> in
# the -> the
# development -> development
# of -> of
# India -> India
# ’s -> ’s
# atomic -> atomic
# energy -> energy
# program -> program
# . -> .
#
# Named Entities:
# Homi Jehangir Bhabha - PERSON
# Indian - NORP
# India - GPE

# %% [markdown]
# Question 10: Chatbot Architecture using LSTM/GRU
# Architecture
#
# User Input Layer
#
# Preprocessing Layer (spaCy / Stanford NLP)
#
# Embedding Layer
#
# LSTM / GRU Model
#
# Intent Classification Layer
#
# Response Generation Module
#
# Data Preprocessing Pipeline
#
# Steps include:
#
# Text cleaning
#
# Tokenization (spaCy)
#
# Lemmatization
#
# Stop-word removal
#
# Word embeddings (Word2Vec / GloVe)
# User Input
# ↓
# spaCy preprocessing
# ↓
# Word embeddings
# ↓
# LSTM / GRU network
# ↓
# Intent classification
# ↓
# Response generation

# %%
from tensorflow.keras.layers import GRU

model = Sequential()
model.add(Embedding(1000, 64))
model.add(GRU(64))
model.add(Dense(10, activation='softmax'))
